# %% [markdown]
# # Soal 7
#
# The following table gives the 1996 SAT mean math and verbal scores in each state and the District of Columbia, along with the percentage of the states’ graduating high school students that took the examination. Use data relating to the first 20 locations listed (Alabama to Maine) to develop a prediction of the mean student mathematics score in terms of the percentage of students that take the examination. Then compare your predicted values for the next 5 states (based on the percentage taking the exam in these states) with the actual mean math scores.
#
# ```
# Locations = "Alabama", "Alaska", "Taking SAT", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Dist of Columbia", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "NewYork", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming", "National Average"
#
# Verbal = 565, 521, 525, 566, 495, 536, 507, 508, 489, 498, 484, 485, 543, 564, 494, 590, 579, 549, 559, 504, 507, 507, 557, 582, 569, 570, 546, 567, 508, 520, 498, 554, 497, 490, 596, 536, 566, 523, 498, 501, 480, 574, 563, 495, 583, 506, 507, 519, 526, 577, 544, 505
#
# Math = 558, 513, 521, 550, 511, 538, 504, 495, 473, 496, 477, 510, 536, 575, 494, 600, 571, 544, 550, 498, 504, 504, 565, 593, 557, 569, 547, 568, 507, 514, 505, 548, 499, 486, 599, 535, 557, 521, 492, 491, 474, 566, 552, 500, 575, 500, 496, 519, 506, 586, 544, 508
#
# Graduates Percentage = 8, 47, 28, 6, 45, 30, 79, 66, 50, 48, 63, 54, 15, 14, 57, 5, 9, 12, 9, 68, 64, 80, 11, 9, 4, 9, 21, 9, 31, 70, 69, 12, 73, 59, 5, 24, 8, 50, 71, 69, 57, 5, 14, 48, 4, 70, 68, 47, 17, 8, 11, 41
#
# ```

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %% [markdown]
# Inisialisasi variabel

# %%
locations_all = ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Dist of Columbia", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "NewYork", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming", "National Average"]

math_all = np.array([558, 513, 521, 550, 511, 538, 504, 495, 473, 496, 477, 510, 536, 575, 494, 600, 571, 544, 550, 498, 504, 504, 565, 593, 557, 569, 547, 568, 507, 514, 505, 548, 499, 486, 599, 535, 557, 521, 492, 491, 474, 566, 552, 500, 575, 500, 496, 519, 506, 586, 544, 508]).reshape(-1, 1)

percentage_all = np.array([8, 47, 28, 6, 45, 30, 79, 66, 50, 48, 63, 54, 15, 14, 57, 5, 9, 12, 9, 68, 64, 80, 11, 9, 4, 9, 21, 9, 31, 70, 69, 12, 73, 59, 5, 24, 8, 50, 71, 69, 57, 5, 14, 48, 4, 70, 68, 47, 17, 8, 11, 41])

# %% [markdown]
# #### First 20 data

# %%
first_20_location = locations_all[:20]
first_20_math = math_all[:20]
first_20_percentage = percentage_all[:20]

mean_20_math = np.mean(first_20_math)
print(f"Mean for 20 first data = {mean_20_math}")
# Out:
# Mean for 20 first data = 525.7

# %% [markdown]
# Data visualitation for first 20 data

# %%
# Membuat model regresi linear
model = LinearRegression()

# Melatih model menggunakan data
model.fit(first_20_math, first_20_percentage)

# Melakukan prediksi
y_pred = model.predict(first_20_math)

# Menampilkan koefisien dan intersep dari garis regresi
print(f"Koefisien: {model.coef_}")
print(f"Intersep: {model.intercept_}")

plt.figure(figsize=(10, 6))
plt.scatter(first_20_math, first_20_percentage, color='blue', label='Actual data')
plt.plot(first_20_math, model.predict(first_20_math), color='red', label='Regression line')
plt.xlabel('Math Score')
plt.ylabel('Percentage')
plt.title("Regresi Linear")
plt.legend()
plt.grid()
plt.show()
# Out:
# Koefisien: [-0.61555317]
# Intersep: 359.24629885989884

# %% [markdown]
# #### First 20 data + 5 data extra

# %%
extra_5_math = math_all[20:25]
extra_5_percentage = percentage_all[20:25]

# %% [markdown]
# Data visualitation for first 20 data + 5 data extra

# %%
# Membuat model regresi linear
model_2 = LinearRegression()

# Melatih model menggunakan data
model_2.fit(extra_5_math, extra_5_percentage)

# Melakukan prediksi
y_pred = model_2.predict(extra_5_math)

# Menampilkan koefisien dan intersep dari garis regresi
print(f"Koefisien: {model_2.coef_}")
print(f"Intersep: {model_2.intercept_}")
# Out:
# Koefisien: [-0.82728854]
# Intersep: 484.14133865876454

# %%
plt.figure(figsize=(10, 6))
plt.scatter(first_20_math, first_20_percentage, color='blue', label='20 first data')
plt.scatter(extra_5_math, extra_5_percentage, color='green', label='5 extra data')
plt.plot(first_20_math, model.predict(first_20_math), color='red', label='Regression line 20 first data')
plt.plot(extra_5_math, model.predict(extra_5_math), color='yellow', label='Regression line 5 extra data')
plt.xlabel('Math Score')
plt.ylabel('Percentage')
plt.title("Regresi Linear")
plt.legend()
plt.grid()
plt.show()
